# %%
df = spark.sql("SELECT * FROM user_data")
display(df)
df.write.mode("overwrite").csv("/user_data/csvfiles")
df.write.mode("overwrite").parquet("/user_data/parquetfiles")
# Out:
# StatementMeta(sparkpool, 7, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, fb7ad254-acd4-4a05-aef6-96a52f61da22)
